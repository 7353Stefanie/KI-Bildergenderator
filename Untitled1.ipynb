# %% [markdown]
# <a href="https://colab.research.google.com/github/7353Stefanie/KI-Bildergenderator/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/lora-hase /content/drive/MyDrive/
# Out:
# cp: cannot stat '/content/lora-hase': No such file or directory

# %%
# !cp -r /content/lora-hase /content/drive/MyDrive/
# !pip install bitsandbytes
# !pip install git+https://github.com/huggingface/diffusers.git
# !pip install xformers==0.0.29.post1 --index-url https://download.pytorch.org/whl/cu124
# !pip install torch==2.1.0 torchvision==0.16.0 --force-reinstall
# !pip install numpy==1.24.4 torch==2.1.0 torchvision==0.16.0
# !pip install accelerate==0.28.0 diffusers==0.27.2 transformers==4.40.1
# !pip install peft==0.11.1  # oder passende Version für dein Setup
# Out:
# cp: cannot stat '/content/lora-hase': No such file or directory
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 849.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.3 MB/s eta 0:00:00
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch
from IPython.display import display

# 2.Basis-Modell laden

pipe = StableDiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2-1",
    torch_dtype=torch.float16
).to("cuda")

# LoRA-Gewichte laden / 3. Die Inhalte für die KI laden (weights)

pipe.load_lora_weights("/content/drive/MyDrive/lora-hase")

# Bild generieren / 4. Bild mit Prompt generieren

prompt = "a cartoon bunny with a hat at the head in black and white as a drawable picture for kids, very light background, no gray"
image = pipe(prompt, num_inference_steps=30, guidance_scale=7.5).images[0]

# Anzeigen 5. 5. Bild anzeigen lassen

display(image)
# @title
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-7-3475321742.py in <cell line: 0>()
# ----> 1 from diffusers import StableDiffusionPipeline
#       2 import torch
#       3 from IPython.display import display
#       4
#       5 # 2.Basis-Modell laden
#
# /usr/local/lib/python3.11/dist-packages/diffusers/__init__.py in <module>
#       3 from typing import TYPE_CHECKING
#       4
# ----> 5 from .utils import (
#       6     DIFFUSERS_SLOW_IMPORT,
#       7     OptionalDependencyNotAvailable,
#
# /usr/local/lib/python3.11/dist-packages/diffusers/utils/__init__.py in <module>
#      36 from .deprecation_utils import deprecate
#      37 from .doc_utils import replace_example_docstring
# ---> 38 from .dynamic_modules_utils import get_class_from_dynamic_module
#      39 from .export_utils import export_to_gif, export_to_obj, export_to_ply, export_to_video
# ...

# %%
# !pip uninstall -y diffusers huggingface_hub
# !pip install diffusers==0.17.1 huggingface_hub==0.16.4
# !pip install numpy==1.24.4 torch==2.1.0 torchvision==0.16.0
# Out:
# WARNING: Skipping diffusers as it is not installed.
# WARNING: Skipping huggingface_hub as it is not installed.
# ...
#   Using cached huggingface_hub-0.16.4-py3-none-any.whl.metadata (12 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 7.2 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.11.1 requires huggingface-hub>=0.17.0, but you have huggingface-hub 0.16.4 which is incompatible.
# transformers 4.40.1 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 0.16.4 which is incompatible.
# gradio 5.31.0 requires huggingface-hub>=0.28.1, but you have huggingface-hub 0.16.4 which is incompatible.
# gradio-client 1.10.1 requires huggingface-hub>=0.19.3, but you have huggingface-hub 0.16.4 which is incompatible.
# ...

# %% [markdown]
# # Neuer Abschnitt

# %%
from diffusers import StableDiffusionPipeline
import torch
from IPython.display import display

# 2.Basis-Modell laden

pipe = StableDiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2-1",
    torch_dtype=torch.float16
).to("cuda")

# LoRA-Gewichte laden / 3. Die Inhalte für die KI laden (weights)

#pipe.load_lora_weights("/content/drive/MyDrive/lora-hase", weight_name="pytorch_lora_weights.safetensors")
pipe.load_lora_weights(
    [
        ("/content/drive/MyDrive/lora-hase/pytorch_lora_weights.safetensors", 0.5),  # 80 % Hase
        ("/content/drive/MyDrive/lora-hase2/pytorch_lora_weights.safetensors", 0.5)  # 50 % Zebra
    ]
)


# Bild generieren / 4. Bild mit Prompt generieren

prompt = "a cartoon bunny in black and white as a drawable picture for kids, white background, no gray"
image = pipe(prompt, num_inference_steps=30, guidance_scale=7.5).images[0]

# Anzeigen 5. 5. Bild anzeigen lassen

display(image)
# @title
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-5-1680974807.py in <cell line: 0>()
#       8     "stabilityai/stable-diffusion-2-1",
#       9     torch_dtype=torch.float16
# ---> 10 ).to("cuda")
#      11
#      12 # LoRA-Gewichte laden / 3. Die Inhalte für die KI laden (weights)
#
# /content/diffusers/src/diffusers/pipelines/pipeline_utils.py in to(self, *args, **kwargs)
#     539                 module.to(device=device)
#     540             elif not is_loaded_in_4bit_bnb and not is_loaded_in_8bit_bnb and not is_group_offloaded:
# --> 541                 module.to(device, dtype)
#     542
#     543             if (
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in to(self, *args, **kwargs)
# ...

# %%
# !pip uninstall -y peft
# !pip install peft>=0.15.0
# Out:
# Found existing installation: peft 0.15.2
# Uninstalling peft-0.15.2:
#   Successfully uninstalled peft-0.15.2

# %%
# !pip install --upgrade diffusers transformers accelerate safetensors
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 68.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
# ...

# %%
pretrained_model_name_or_path = "stabilityai/stable-diffusion-2-1-base"
instance_data_dir = "/content/drive/MyDrive/Hase2/Hase2"
output_dir = "/content/drive/MyDrive/lora-my-style"
instance_prompt = "a rabbit in black and white as a drawable picture for kids, white background"  # z. B. "a painting in the style of xyz"

resolution = 512
train_batch_size = 1
num_train_epochs = 10  # 20–30 = stärkerer Stil
checkpointing_steps = 500

# !accelerate launch "/content/diffusers/examples/dreambooth/train_dreambooth_lora.py" \
  --pretrained_model_name_or_path="stabilityai/stable-diffusion-2-1" \
  --instance_data_dir="/content/drive/MyDrive/Hase2/Hase2" \
  --output_dir="/content/drive/MyDrive/lora-hase2" \
  --instance_prompt="a rabbit as a black-and-white line drawing for kids" \
  --resolution=512 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-4 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_train_epochs=10 \
  --checkpointing_steps=500 \
  --seed=1337 \
  --mixed_precision="fp16" \
  --use_8bit_adam \
# Out:
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-06-30 18:07:03.421910: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 12.0 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade --force-reinstall torchvision --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 107.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.5/780.5 MB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 98.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 115.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB ? eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 804.3 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall -y xformers
# !pip install xformers==0.0.26.post1
# Out:
# WARNING: Skipping xformers as it is not installed.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.2/779.2 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 114.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 48.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 713.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
# ...

# %%
# !pip install -U peft>=0.15.0

# %%
# !git clone https://github.com/huggingface/diffusers.git
# %cd diffusers
# !pip install -e .
# !pip install -r examples/dreambooth/requirements.txt
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 97632, done.
# remote: Counting objects: 100% (1747/1747), done.
# remote: Compressing objects: 100% (704/704), done.
# remote: Total 97632 (delta 1498), reused 1043 (delta 1043), pack-reused 95885 (from 4)
# Receiving objects: 100% (97632/97632), 74.29 MiB | 14.98 MiB/s, done.
# Resolving deltas: 100% (71629/71629), done.
# /content/diffusers
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.35.0.dev0-0.editable-py3-none-any.whl size=11365 sha256=da8c2589c221f79691ce1f63914b44700fc1e622baf5b7639bf87b23d09821db
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp -r /content/lora-hase /content/drive/MyDrive/
# Out:
# Mounted at /content/drive
# cp: cannot stat '/content/lora-hase': No such file or directory

# %%
# Bereinige veraltete Versionen
# !pip uninstall -y diffusers huggingface_hub

# Installiere kompatible aktuelle Versionen
# !pip install diffusers==0.27.2 huggingface_hub==0.28.1 --no-cache-dir --force-reinstall
# Out:
# Found existing installation: diffusers 0.34.0
# Uninstalling diffusers-0.34.0:
#   Successfully uninstalled diffusers-0.34.0
# Found existing installation: huggingface-hub 0.33.0
# Uninstalling huggingface-hub-0.33.0:
#   Successfully uninstalled huggingface-hub-0.33.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 153.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 155.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 42.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.1/464.1 kB 227.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 171.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 156.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 227.7 MB/s eta 0:00:00
# ...

# %%
# !pip install torch==2.5.1 torchvision==0.18.1 --index-url https://download.pytorch.org/whl/cu121
# !pip install diffusers==0.27.2 transformers==4.41.0 accelerate==0.29.2
# !pip install peft==0.15.1
# !pip install huggingface_hub==0.28.1
# !pip install bitsandbytes  # nur CPU oder deaktivierte GPU-Version
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#   Using cached https://download.pytorch.org/whl/cu121/torch-2.5.1%2Bcu121-cp311-cp311-linux_x86_64.whl (780.5 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/torchvision-0.18.1%2Bcu121-cp311-cp311-linux_x86_64.whl (7.0 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %%
# ✅ Modell laden
pipe = StableDiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2-1",
    torch_dtype=torch.float16
).to("cuda")

# ✅ Testbild generieren
prompt = "a cute cartoon rabbit riding a skateboard"
image = pipe(prompt).images[0]
image.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-15-367786388.py in <cell line: 0>()
#       1 # ✅ Modell laden
# ----> 2 pipe = StableDiffusionPipeline.from_pretrained(
#       3     "stabilityai/stable-diffusion-2-1",
#       4     torch_dtype=torch.float16
#       5 ).to("cuda")
#
# NameError: name 'StableDiffusionPipeline' is not defined

# %%
# !pip install numpy==1.24.4 --force-reinstall
# Out:
# ...
#   Using cached numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Using cached numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bitsandbytes 0.46.0 requires torch<3,>=2.2, but you have torch 2.1.0 which is incompatible.
# xformers 0.0.29.post1 requires torch==2.5.1, but you have torch 2.1.0 which is incompatible.
# peft 0.11.1 requires huggingface-hub>=0.17.0, but you have huggingface-hub 0.16.4 which is incompatible.
# transformers 4.40.1 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 0.16.4 which is incompatible.
# ...

# %%
# !pip install accelerate==0.29.2 --upgrade --force-reinstall --no-cache-dir
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 174.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.4/297.4 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 221.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 203.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 258.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 181.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 123.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 112.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 198.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 208.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 129.5 MB/s eta 0:00:00
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch

# Basis-Modell laden
pipe = StableDiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2-1",
    torch_dtype=torch.float16
).to("cuda")

# LoRA-Gewichte laden
pipe.load_lora_weights("/content/drive/MyDrive/lora-hase")

# Bild generieren
prompt = "a cute cartoon bunny in the forest, colorful, soft lighting"
image = pipe(prompt, num_inference_steps=30, guidance_scale=7.5).images[0]

# Anzeigen
image.show()
# Out:
# WARNING:bitsandbytes.cextension:The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers and GPU quantization are unavailable.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/diffusers/utils/import_utils.py in _get_module(self, module_name)
#     882         try:
# --> 883             return importlib.import_module("." + module_name, self.__name__)
#     884         except Exception as e:
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ...

# %%
# !pip install --upgrade peft
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.1/411.1 kB 6.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: peft
#     Found existing installation: peft 0.11.1
#     Uninstalling peft-0.11.1:
#       Successfully uninstalled peft-0.11.1
# ...

# %%
# !pip uninstall -y bitsandbytes

# Installiert bitsandbytes mit GPU-Support (Standardpaket, wenn verfügbar)
# !pip install bitsandbytes --prefer-binary --upgrade
# Out:
# WARNING: Skipping bitsandbytes as it is not installed.
# ...
#   Using cached bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# ...
# Using cached bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
# ...

# %%
# Bereinige die fehlerhaften Installationen
# !pip uninstall -y diffusers huggingface_hub

# Installiere neue, zueinander passende Versionen
# !pip install diffusers==0.27.2 huggingface_hub==0.28.1
# Out:
# Found existing installation: diffusers 0.27.2
# Uninstalling diffusers-0.27.2:
#   Successfully uninstalled diffusers-0.27.2
# Found existing installation: huggingface-hub 0.28.1
# Uninstalling huggingface-hub-0.28.1:
#   Successfully uninstalled huggingface-hub-0.28.1
# ...
#   Using cached diffusers-0.27.2-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached huggingface_hub-0.28.1-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached diffusers-0.27.2-py3-none-any.whl (2.0 MB)
# Using cached huggingface_hub-0.28.1-py3-none-any.whl (464 kB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# timm 1.0.15 requires torchvision, which is not installed.
# ...

# %%
# !pip uninstall -y numpy
# !pip install numpy==1.24.4 --force-reinstall
# Out:
# Found existing installation: numpy 1.24.4
# Uninstalling numpy-1.24.4:
#   Successfully uninstalled numpy-1.24.4
# ...
#   Using cached numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Using cached numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bitsandbytes 0.46.0 requires torch<3,>=2.2, but you have torch 2.1.0 which is incompatible.
# xformers 0.0.29.post1 requires torch==2.5.1, but you have torch 2.1.0 which is incompatible.
# peft 0.11.1 requires huggingface-hub>=0.17.0, but you have huggingface-hub 0.16.4 which is incompatible.
# transformers 4.40.1 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 0.16.4 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# ...

# %%
# 🔁 Entferne installierte Versionen
# !pip uninstall -y diffusers huggingface_hub

# ✅ Klone aktuelles diffusers-Repo
# !git clone https://github.com/huggingface/diffusers.git
# %cd diffusers

# ✅ Installiere die Bibliothek lokal
# !pip install .  # installiert aktuelle lokale Version
# !pip install huggingface_hub==0.28.1
# Out:
# Found existing installation: diffusers 0.35.0.dev0
# Uninstalling diffusers-0.35.0.dev0:
#   Successfully uninstalled diffusers-0.35.0.dev0
# Found existing installation: huggingface-hub 0.28.1
# Uninstalling huggingface-hub-0.28.1:
#   Successfully uninstalled huggingface-hub-0.28.1
# fatal: destination path 'diffusers' already exists and is not an empty directory.
# /content/diffusers
# Processing /content/diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached huggingface_hub-0.33.1-py3-none-any.whl.metadata (14 kB)
# ...
# Using cached huggingface_hub-0.33.1-py3-none-any.whl (515 kB)
# ...
#   Created wheel for diffusers: filename=diffusers-0.35.0.dev0-py3-none-any.whl size=3789394 sha256=62e521b853e440bcceea9456f4e92883af96c6469d4587cac0e15bade53c79ef
#   Stored in directory: /tmp/pip-ephem-wheel-cache-te6tpi3t/wheels/30/15/ca/ab6e88c89d6ba7047b3f155894c6c346e7cf06067fd132ae62
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2-1",
    torch_dtype=torch.float16
).to("cuda")

pipe("a futuristic city in the clouds").images[0].show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-3-4211509187.py in <cell line: 0>()
# ----> 1 from diffusers import StableDiffusionPipeline
#       2 import torch
#       3
#       4 pipe = StableDiffusionPipeline.from_pretrained(
#       5     "stabilityai/stable-diffusion-2-1",
#
# /usr/local/lib/python3.11/dist-packages/diffusers/__init__.py in <module>
#       3 from typing import TYPE_CHECKING
#       4
# ----> 5 from .utils import (
#       6     DIFFUSERS_SLOW_IMPORT,
#       7     OptionalDependencyNotAvailable,
#
# /usr/local/lib/python3.11/dist-packages/diffusers/utils/__init__.py in <module>
#      36 from .deprecation_utils import deprecate
#      37 from .doc_utils import replace_example_docstring
# ---> 38 from .dynamic_modules_utils import get_class_from_dynamic_module
# ...

# %%
# !pip uninstall -y diffusers huggingface_hub

# ✅ Kompatible, aktuelle Versionen installieren (keine veralteten Importe mehr)
# !pip install --no-cache-dir diffusers==0.27.2 huggingface_hub==0.28.1
# Out:
# Found existing installation: diffusers 0.27.2
# Uninstalling diffusers-0.27.2:
#   Successfully uninstalled diffusers-0.27.2
# Found existing installation: huggingface-hub 0.28.1
# Uninstalling huggingface-hub-0.28.1:
#   Successfully uninstalled huggingface-hub-0.28.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.1/464.1 kB 147.0 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# timm 1.0.15 requires torchvision, which is not installed.
# ...

# %%
# !pip uninstall -y numpy
# !pip install numpy==1.24.4 --force-reinstall --no-cache-dir
# Out:
# Found existing installation: numpy 1.24.4
# Uninstalling numpy-1.24.4:
#   Successfully uninstalled numpy-1.24.4
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 218.7 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bitsandbytes 0.46.0 requires torch<3,>=2.2, but you have torch 2.1.0 which is incompatible.
# xformers 0.0.29.post1 requires torch==2.5.1, but you have torch 2.1.0 which is incompatible.
# peft 0.11.1 requires huggingface-hub>=0.17.0, but you have huggingface-hub 0.16.4 which is incompatible.
# transformers 4.40.1 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 0.16.4 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# gradio 5.31.0 requires huggingface-hub>=0.28.1, but you have huggingface-hub 0.16.4 which is incompatible.
# ...

# %%
# 🔁 Bereinige und installiere kompatible Versionen
# !pip uninstall -y torch torchvision numpy diffusers transformers huggingface_hub xformers bitsandbytes peft sentence-transformers

# ✅ Installation stabiler, kompatibler Versionen
# !pip install torch==2.5.1 torchvision==0.18.1 --index-url https://download.pytorch.org/whl/cu121
# !pip install numpy==1.26.4
# !pip install diffusers==0.27.2 transformers==4.41.0 huggingface_hub==0.28.1
# !pip install xformers==0.0.29.post1 bitsandbytes==0.43.1 peft==0.11.1 sentence-transformers==4.1.0
# Out:
# Found existing installation: torch 2.5.1
# Uninstalling torch-2.5.1:
#   Successfully uninstalled torch-2.5.1
# WARNING: Skipping torchvision as it is not installed.
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: diffusers 0.27.2
# Uninstalling diffusers-0.27.2:
#   Successfully uninstalled diffusers-0.27.2
# Found existing installation: transformers 4.41.0
# Uninstalling transformers-4.41.0:
#   Successfully uninstalled transformers-4.41.0
# Found existing installation: huggingface-hub 0.28.1
# Uninstalling huggingface-hub-0.28.1:
#   Successfully uninstalled huggingface-hub-0.28.1
# Found existing installation: xformers 0.0.29.post1
# Uninstalling xformers-0.0.29.post1:
#   Successfully uninstalled xformers-0.0.29.post1
# Found existing installation: bitsandbytes 0.43.1
# Uninstalling bitsandbytes-0.43.1:
#   Successfully uninstalled bitsandbytes-0.43.1
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2-1",
    torch_dtype=torch.float16,
    use_safetensors=True
).to("cuda")

pipe.enable_xformers_memory_efficient_attention()

image = pipe("a futuristic robot city in sunset").images[0]
image.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2-1793752628.py in <cell line: 0>()
# ----> 1 from diffusers import StableDiffusionPipeline
#       2 import torch
#       3
#       4 pipe = StableDiffusionPipeline.from_pretrained(
#       5     "stabilityai/stable-diffusion-2-1",
#
# /usr/local/lib/python3.11/dist-packages/diffusers/__init__.py in <module>
#       3 from typing import TYPE_CHECKING
#       4
# ----> 5 from .utils import (
#       6     DIFFUSERS_SLOW_IMPORT,
#       7     OptionalDependencyNotAvailable,
#
# /usr/local/lib/python3.11/dist-packages/diffusers/utils/__init__.py in <module>
#      36 from .deprecation_utils import deprecate
#      37 from .doc_utils import replace_example_docstring
# ---> 38 from .dynamic_modules_utils import get_class_from_dynamic_module
# ...
